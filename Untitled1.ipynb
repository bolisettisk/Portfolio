# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("shootings.csv")
dat_o = pd.read_csv("shootings.csv")

# %%
data.head(10)
# Out:
#    id                 name        date   manner_of_death       armed   age  \
# 0   3           Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0
# 5  11    Kenneth Joe Brown  2015-01-04              shot         gun  18.0
# 6  13  Kenneth Arnold Buck  2015-01-05              shot         gun  22.0
# 7  15        Brock Nichols  2015-01-06              shot         gun  35.0
# 8  16        Autumn Steele  2015-01-06              shot     unarmed  34.0
# 9  17      Leslie Sapp III  2015-01-06              shot  toy weapon  47.0
#
#   gender      race           city state  signs_of_mental_illness threat_level  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["race"].unique()
# Out:
# array(['Asian', 'White', 'Hispanic', 'Black', 'Other', 'Native'],
#       dtype=object)

# %%
races = pd.get_dummies(data["race"], drop_first=True)

# %%
data = pd.concat([data, races], axis=1)

# %%
data.drop("race", axis=1, inplace=True)

# %%
data.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender           city state  signs_of_mental_illness threat_level  \
# 0      M        Shelton    WA                     True       attack
# 1      M          Aloha    OR                    False       attack
# 2      M        Wichita    KS                    False        other
# 3      M  San Francisco    CA                     True       attack
# 4      M          Evans    CO                    False       attack
#
#           flee  body_camera          arms_category  Black  Hispanic  Native  \
# ...

# %%
obj = data.groupby("city")

# %%
data["manner_of_death"].nunique()
# Out:
# 2

# %%
len(data["manner_of_death"])
# Out:
# 4895

# %%
x = data["manner_of_death"]
sht = np.zeros(len(x))
c=0
for i in x:
    if i == "shot":
        sht[c] = 1
    else:
        sht[c] = 0
    c = c+1
s =  {"shot": sht}
shot = pd.DataFrame(s)

# %%
data.drop("manner_of_death", axis=1, inplace=True)

# %%
data = pd.concat([data, shot], axis=1)

# %%
data.head()
# Out:
#    id                name        date       armed   age gender           city  \
# 0   3          Tim Elliot  2015-01-02         gun  53.0      M        Shelton
# 1   4    Lewis Lee Lembke  2015-01-02         gun  47.0      M          Aloha
# 2   5  John Paul Quintero  2015-01-03     unarmed  23.0      M        Wichita
# 3   8     Matthew Hoffman  2015-01-04  toy weapon  32.0      M  San Francisco
# 4   9   Michael Rodriguez  2015-01-04    nail gun  39.0      M          Evans
#
#   state  signs_of_mental_illness threat_level         flee  body_camera  \
# 0    WA                     True       attack  Not fleeing        False
# 1    OR                    False       attack  Not fleeing        False
# 2    KS                    False        other  Not fleeing        False
# 3    CA                     True       attack  Not fleeing        False
# 4    CO                    False       attack  Not fleeing        False
#
# ...

# %%
dat_o.groupby("race").mean()
# Out:
#                    id        age  signs_of_mental_illness  body_camera
# race
# Asian     3162.225806  36.561676                 0.258065     0.172043
# Black     2944.973035  32.549946                 0.141757     0.157165
# Hispanic  2909.364745  33.683847                 0.174058     0.117517
# Native    2922.756410  31.732281                 0.179487     0.153846
# Other     2566.437500  33.064957                 0.229167     0.125000
# White     2873.159935  39.909488                 0.287964     0.094507
