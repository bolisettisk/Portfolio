# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
stocks = pd.read_csv("KS.csv")

# %%
df = pd.DataFrame(stocks)
df.head()
# Out:
#          Date      Open      High       Low     Close      Adj Close  Volume
# 0  2016-01-04  147500.0  148000.0  143500.0  144000.0  122929.101563  445332
# 1  2016-01-05  143000.0  145000.0  142000.0  143500.0  122502.289063  530496
# 2  2016-01-06  144000.0  145000.0  139000.0  140000.0  119514.398438  769406
# 3  2016-01-07  138500.0  140000.0  137500.0  137500.0  117380.210938  586187
# 4  2016-01-08  134500.0  138000.0  133500.0  136500.0  116526.562500  888701

# %%
[df["Close"].max(), df["Close"].min(), df["Close"].mean(), df["Close"].median()]
# Out:
# [267500.0, 65900.0, 154466.18839675607, 144500.0]

# %%
boxplot = df.boxplot(figsize = (5,5), column = ['Open'])

# %%
boxplot = df.boxplot(figsize = (5,5), column = ['Close'])

# %%
df.plot.scatter(y = "Close", x = "Date")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
df.plot.scatter(y = "Open", x = "Date")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
corr = df.corr()
corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.998434  0.998828  0.997503   0.985399  0.133942
# High       0.998434  1.000000  0.998081  0.998908   0.986862  0.164426
# Low        0.998828  0.998081  1.000000  0.998663   0.986117  0.118787
# Close      0.997503  0.998908  0.998663  1.000000   0.987340  0.144390
# Adj Close  0.985399  0.986862  0.986117  0.987340   1.000000  0.182122
# Volume     0.133942  0.164426  0.118787  0.144390   0.182122  1.000000

# %%
corr.style.background_gradient(cmap = "coolwarm")
# Out:
# <style type="text/css">
# #T_5e266_row0_col0, #T_5e266_row0_col1, #T_5e266_row0_col2, #T_5e266_row0_col3, #T_5e266_row1_col0, #T_5e266_row1_col1, #T_5e266_row1_col2, #T_5e266_row1_col3, #T_5e266_row2_col0, #T_5e266_row2_col1, #T_5e266_row2_col2, #T_5e266_row2_col3, #T_5e266_row3_col0, #T_5e266_row3_col1, #T_5e266_row3_col2, #T_5e266_row3_col3, #T_5e266_row4_col4, #T_5e266_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5e266_row0_col4, #T_5e266_row1_col4, #T_5e266_row2_col4, #T_5e266_row4_col0, #T_5e266_row4_col1, #T_5e266_row4_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_5e266_row0_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_5e266_row1_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5e266_row2_col5, #T_5e266_row5_col0, #T_5e266_row5_col1, #T_5e266_row5_col2, #T_5e266_row5_col3, #T_5e266_row5_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5e266_row3_col4, #T_5e266_row4_col3 {
# ...
